# %%
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score

from sklearn.model_selection import train_test_split
from sklearn import metrics
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
expr = pd.read_csv("data/expresion_matrix.csv")
expr.head()
# Out:
#               WASH7P  RP11-34P13.7    CICP27  AL627309.1  RP11-34P13.15  \
# ACH-000956  1.134038      2.145153  1.396459    1.735286        0.00000
# ACH-000323  1.865275      2.513380  0.559418    1.051912        0.00000
# ACH-000905  2.692535      2.769543  0.647189    1.954041        0.15056
# ACH-000973  2.165830      2.782041  0.566833    1.044218        0.00000
# ACH-000070  0.050187      2.037069  0.808068    1.544984        0.00000
#
#             RP11-34P13.14  RP11-34P13.13  AP006222.2  RP4-669L17.10  \
# ACH-000956       0.018505       1.835159    2.400994       4.177105
# ACH-000323       0.096828       1.799706    0.608955       2.571064
# ACH-000905       0.354248       1.755331    0.543573       2.778809
# ACH-000973       1.141376       2.174128    1.196978       4.052510
# ACH-000070       0.053310       0.090498    1.009920       4.296848
#
#             RP4-669L17.8  ...    MT-CO2   MT-ATP8   MT-ATP6    MT-CO3  \
# ...

# %%
sen = pd.read_csv("data/sensitivity_matrix_Activity_Area.csv", index_col = 0)
sen.head()
# Out:
#             AEW541  Nilotinib  17-AAG  PHA-665752  Lapatinib  Nutlin-3  \
# ACH-000956  1.6723     0.1278  3.0622      0.9168     0.5246    0.7904
# ACH-000323  1.1852        NaN  5.0587      1.0796     0.6577    0.8625
# ACH-000905  0.9948     0.5269  3.5350      0.0000     1.0890    0.0000
# ACH-000973  1.5436     0.5869  3.7820      0.3701     0.1402    0.2235
# ACH-000070  1.7665     2.1147  3.6605      1.8775     1.5649    2.7720
#
#             AZD0530  PF2341066  L-685458  ZD-6474  ...  LBW242  PD-0325901  \
# ACH-000956   0.6198     0.8545   0.08479   0.4765  ...  0.4906      2.8355
# ACH-000323   1.9068     0.9563   1.14480   2.8994  ...  1.3794      1.2940
# ACH-000905   0.8491     0.1933   0.16570   0.8562  ...  0.2789      0.9413
# ACH-000973   1.2147     0.9721   0.37910   1.7839  ...  0.0185      2.2210
# ACH-000070   1.8525     2.0731   3.63960   2.0536  ...  1.4433      2.5862
#
#             PD-0332991  Paclitaxel  AZD6244  PLX4720  RAF265  TAE684  TKI258  \
# ...

# %%
X = np.array(expr)

# %%
model = KMeans(n_clusters=3, random_state=0, n_init="auto")
# model = AgglomerativeClustering(n_clusters=3)
kmeans = model.fit(X)
labels = kmeans.labels_

# %%
k_predefined = [2, 3, 4, 5]
sil_score = []

for k in k_predefined:
    model = KMeans(n_clusters=k, random_state=0, n_init="auto")
    kmeans = model.fit(X)
    labels = kmeans.labels_
    sc = silhouette_score(X, labels).item()
    sil_score.append(sc)
sil_score
# Out:
# [0.13070372461610316,
#  0.0830460155931865,
#  0.07434383458444785,
#  0.07367913848881501]
